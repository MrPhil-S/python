# %%
import pandas as pd

potholes = pd.read_csv('D:\Phillycheese\Downloads\get_it_done_311_pothole_requests_data_SD.csv', parse_dates=True, index_col='service_request_id')
print(potholes)
#print(customers.columns)
# Out:
#                     parent_case_number status_description mobile_web_status  \
# service_request_id
# 268608                               0       Acknowledged        In process
# 268588                               0                New               New
# 268580                               0                New               New
# 268577                               0                New               New
# 268565                               0                New               New
# ...                                ...                ...               ...
# 80577                                0             Closed            Closed
# 80547                                0             Closed            Closed
# 80543                                0             Closed            Closed
# 80531                                0             Closed            Closed
# 80518                                0             Closed            Closed
#
# ...
