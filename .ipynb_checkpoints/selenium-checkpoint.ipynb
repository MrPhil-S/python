# %%
from selenium import webdriver

#options = webdriver.ChromeOptions()
#options.add_argument('headless')
#PATH = "C:\ProgramData\Anaconda3\Lib\site-packages\chromedriver_py\chromedriver.exe"
#browser = webdriver.Chrome(PATH)
#options = webdriver.ChromeOptions()
#options.add_experimental_option('excludeSwitches', ['enable-logging'])
#driver = webdriver.Chrome(executable_path='<path-to-chrome>', options=options)
#browser = webdriver.PhantomJS(executable_path = r"c:\programdata\anaconda3\lib\site-packages")
url = "https://finance.yahoo.com/quote/MSFT/key-statistics?p=MSFT"

browser = webdriver.Firefox()

browser.get(url)
#print(browser.page_source)

element = browser.find_element_by_xpath("html")
#print(element.tag_name)
#print(element.text) ##just high-level text = not really useful
#print(element.get_attribute("textContent"))  ##full tag output - can be used to find what we need


#find 1st element within the ("tag")
#element = browser.find_element_by_xpath("html/*")
#print(element.tag_name)

#navigate the html and find multiple elements
###
elements = browser.find_elements_by_xpath("html/*")
#elements = browser.find_elements_by_xpath("html/head/*")
for element in elements: #= [head, body]
#    print(element.tag_name)    
    newElements = element.find_elements_by_xpath("./*")  # the "./" indicates the current path, "/" indicates the very top element
    for newElement in newElements:
        print(newElement.tag_name)
    print(element.tag_name) 

browser.quit()
# Out:
# script
# meta
# title
# meta
# meta
# meta
# meta
# meta
# meta
# meta
# meta
# meta
# link
# link
# link
# link
# link
# link
# link
# link
# link
# link
# link
# link
# link
# link
# link
# link
# link
# link
# link
# link
# link
# link
# link
# link
# link
# link
# link
# link
# link
# link
# link
# link
# link
# meta
# meta
# meta
# meta
# meta
# meta
# meta
# meta
# meta
# meta
# meta
# meta
# meta
# meta
# link
# link
# link
# script
# script
# script
# style
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# style
# style
# script
# style
# style
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# head
# iframe
# div
# div
# div
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# script
# iframe
# iframe
# body
